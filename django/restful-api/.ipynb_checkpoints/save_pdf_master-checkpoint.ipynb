# %%
# !pip install pdfminer
# Out:
# Collecting pdfminer
#   Using cached pdfminer-20191125.tar.gz (4.2 MB)
# Collecting pycryptodome
#   Using cached pycryptodome-3.10.1-cp35-abi3-macosx_10_9_x86_64.whl (1.5 MB)
# Building wheels for collected packages: pdfminer
#   Building wheel for pdfminer (setup.py) ... done
#   Created wheel for pdfminer: filename=pdfminer-20191125-py3-none-any.whl size=6140081 sha256=8d37e4d7feed759299d08846cc0cba6aac6e4b42ad8f1dabd850cae93c8ccfad
#   Stored in directory: /Users/nahyeonan/Library/Caches/pip/wheels/e3/5e/f4/d210b46e9e4a28229ea070ed5b3efa92c3c29d1a7918dd4b97
# Successfully built pdfminer
# Installing collected packages: pycryptodome, pdfminer
# Successfully installed pdfminer-20191125 pycryptodome-3.10.1
# WARNING: You are using pip version 20.3.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/nahyeonan/opt/anaconda3/bin/python3 -m pip install --upgrade pip' command.

# %%
import os

# customize
from pre_inc_pdf import PdfDocument

# %%
path = "/Users/nahyeonan/Downloads/incruit"

# %%
task_list = []
corp_list = []
question_list = []

# %%
for file in os.listdir(path):
    ext = file[-3:]
    tmp_qst = []
    tmp_ans = []

    if ext == 'pdf':
        pdObj = PdfDocument(path + "/" + file)
        q, a = pdObj.extractQAList()

        for i in range(len(q)):
            tmp_qst.append(q[i])
            tmp_ans.append(a[i])
        b = input()
    question_list.append(tmp_qst)
# Out:
# 1. Ctrl+F를 눌러, 보고 싶은 기업명(계열사명)이나 직무를검색하여 원하는 자기소개서 내용을 확인한다!
# - 빙그레 합격자기소개서 모음편수록된 합격 자기소개서 목차기업명(계열사명)빙그레빙그레직무영업관리안전관리12인크루트 합격자소서 모음집 활용방법!
# 2. 합격자기소개서를 토대로 자기소개서를 작성하고 인크루트에서 무료 컨설팅을 받는다!
#
# 1.  빙그레의  인재상에  비춰볼  때,  본인은  어떤  유형의  인재라고  생각하는지  기술해  주세요.(400자)
# 빙그레/  직무  :  영업관리  원문보기
# 2.  해당  직무를  선택한  이유와  직무를  수행함에  있어  본인의  경쟁력은  무엇인지  기술해  주세요(400자)
# [빙그레  웃게  만드는  창의적  사고방식의  인재]대학시절  공모전  및  기획  동아리인  ‘Beproactive'라는  동아리를  신설하게  되었습니다.  하나의  아이디어를고객에게  전달하기까지의  전체적인  프로세스를  공부하며  팀을  구성해  각종  대회에  나갔지만  번번이  쓴잔을마시기  일  수  이었습니다.  원인을  분석한  결과  너무  창의적인  부분에  집착을  했다는  것이었습니다.  다양한사례들을  접하고  아이디어를  구상해나가는  과정에서  새로운  걸  창조하는  것도  중요하지만  사소한  것들,  기존에있었지만  불편한  것들로부터  오는  문제점들을  개선해서  제품화  하는  게  정말  중요하다는  것을  알게  되었습니다.사고의  전환으로  프로젝트를  다시  수행하게  되었으며  이를  통해  ‘무선전력제어기’와  ‘턴스프링  우산’  등으로수상의  영예를  안을  수  있었습니다.
# 3.  본인이  가장  자신있다고  생각하는  것은  무엇이며,  그  이유를  기술해  주세요. (400자)
# [끊임없는  문제해결  자세로  영업을  해결]영업은  의지에  따라  천차만별의  결과가  나오는  매력적인  직무라고  생각합니다.이러한  영업  직무는  어려운상황에서도  끝까지  문제를  해결  하는  능력을  요구하며  이를  위해  다양한  경험을  통해  문제를  해결하는  자세,사고방식을  견지하려고  노력해왔습니다.2012년  여름,폭염  속에서  인천-부산  633km  코스를  자전거로  종주를  
# <'나'보다  '우리'를>  원문보기저는  자신보다는  주변  사람들을  먼저  생각하는  가풍  아래  성장했습니다.  한  예로  중학교  시절  아버지께서  과로로  인해  쓰러지시면서  가족의  생계를  위협받았지만,  가족원들의  희생  덕에  저는  무사히  학업을  마칠  수  있었습니다.  자칫  엇나가기  쉬운  상황이었지만,  평생을  주부로  살다  생계전선에  뛰어든  어머니와  가족을  위해  학업을  포기한  누나들을  생각하면  저를  향한  가족들의  기대를  져버릴  수  없었습니다.  그래서  다른  친구들보다  더  성실히생활하고자  노력했고,  힘든  시기를  함께  이겨내면서  식구들  간의  유대감은  더욱  끈끈해졌습니다.  저는  사람의  진면목은  그  사람이  위기에  처했을  때의  드러난다고  생각합니다.  빙그레의  가족이  된다면  위기의  상황에서  동료와회사를  먼저  생각하는  사원이  되겠습니다.
# 3.  지원동기  및  입사  후  포부(400자  이내)
# <공감의  귀재>다른  사람들의  이야기에  공감하는  능력이  뛰어나다는  점이  제  장점입니다.  흔히  공감  능력은  여성의  특성로  회자되는데,  저는  여성이  많은  가정에서  자란  덕에  다른  사람과  대화하고  상대의  이야기에  공감하는  능력이  탁월합니다.  한편  제  단점은  원칙을  고집하는  경향이  있다는  것입니다.  그래서  때로는  융통성이  없다는  말을  듣기도  합니다.  하지만  제가  지원한  안전관리직의  업무는,  제  임의대로  상황에  따라  유동적으로  움직이기보다는  원리원칙에  충실해야  하는  업무이기에  단점이  외려  장점으로  작용할  수  있다고  생각합니다.제  신조는  '현재에  충실하자'는  것입니다.  과거도  미래도  시점의  차이일  뿐  어느  순간에는  모두  현재이기에  현재에  충실하면  후회할  일도  염려할  일도  없다고  생각하기  때문입니다.
# 4.  경력  및  특기사항(400자  이내)
# <빙그레를  미소  짓게  하는  힘>제가  빙그레에  지원하게  된  이유는  빙그레의  정신에  크게  공감했기  때문입니다.  '서로  사랑하는  마음으로  빙그레웃는  세상을  만들어야겠소.'라는  도산  안창호  선생의  사상을  바탕으로  하는  빙그레의  사상은,  제게  빙그레가  단순한  일터를  넘어  사회를  긍정적으로  이끌어가는  공간이라는  확신을  주었습니다.  이제  빙그레의  일원이  되어  회사와  사회에  보탬이  되는  사람이  되고  싶습니다.빙그레의  가족으로  일하게  된다면  고객과  동료들을  빙그레  미소  짓게  하는  직원이  되겠습니다.  직원이  행복하지않으면  고객을  미소  짓게  할  수  없다고  생각합니다.  언제나  회사와  동료를  먼저  생각하는  사원이  되어  힘이  들때  위로가  되는  동료,  회사가  어려울  때  믿고  의지할  수  있는  직원이  되겠습니다.
# 5.  기타  자기소개(400자  이내)
# <더  나은  미래를  일구다>대학  졸업  후  엔진부품과  센서를  주로  취급하는  OO에  기능직으로  3년  여간  근무한  바  있습니다.  이  과정에서안전관리  업무에  대한  관심이  생겨  산업안전관리기사  자격증을  취득하였으며,  이후  **기업에서  안전관리직으로  2년  여간  근무하며  실무  경험을  쌓았습니다.취업난  속에서  직장을  그만둔다는  것이  결코  쉬운  결심은  아니었습니다.  현실에  안주하고  싶은  마음도  있었지만,제가  하고  싶은  일을  마음껏  하고  싶다는  욕심에  재취업을  결심하게  되었습니다.  제가  **에서  근무할  당시  중소기업체  특성상  다른  업무와  겸직을  해야  하는  경우가  빈번했는데,  그  때마다  안전관리직무에  충실히  임하면서  전문성을  쌓을  수  있는  환경에서  일하고  싶은  마음이  들어  이렇게  재취업을  준비하게  되었습니다.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-55eee2999367> in <module>
#       6 #         ret = pdObj.extractCorpName()
#       7 #         print(pdObj.text)
# ----> 8         q, a = pdObj.extractQAList()
#       9         print(len(a))
#      10         b = input()
#
# TypeError: cannot unpack non-iterable NoneType object
